# %% [markdown]
# <a href="https://colab.research.google.com/github/jurkimanjunath-cyber/Class-python/blob/main/HTML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML

html_content = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <div>ABC</div>
    <div>
            <div>item1</div>
            <div>item2</div>
    </div>
    <div>copyright </div>

</body>
</html>"""

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <div>ABC</div>
#     <div>
#             <div>item1</div>
#             <div>item2</div>
#     </div>
#     <div>copyright </div>
#
# </body>
# </html>

# %%
from IPython.display import HTML

html_content = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <header>ABC</header>
    <main>
            <article>item1</article>
            <article>item2</article>
    </main>
    <footer>copyright </footer>

</body>
</html>"""

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <header>ABC</header>
#     <main>
#             <article>item1</article>
#             <article>item2</article>
#     </main>
#     <footer>copyright </footer>
#
# </body>
# </html>

# %%
from IPython.display import HTML

html_content = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
  <p><u>hello!</u></p>
  <p>&ContourIntegral;x<sup>2</sup></p>
  <p>i am bunny and i live in new&nbsp;hyderabad.</p>
    <footer>&copy;zenith school of AI&trade; </footer>

</body>
</html>"""

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#   <p><u>hello!</u></p>
#   <p>&ContourIntegral;x<sup>2</sup></p>
#   <p>i am bunny and i live in new&nbsp;hyderabad.</p>
#     <footer>&copy;zenith school of AI&trade; </footer>
#
# </body>
# </html>

# %% [markdown]
# &nbsp; its work for not seperate btw two words,when we zoom in and zoom out like new hyderabad

# %%
from IPython.display import HTML

html_content = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
    <h1>Movie lists</h1>
    <p>Inception</p>
    <p>Interstellar</P>
    <p>Fight Club</p>
    <p>Bat Man</p>



</body>
</html>"""

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <h1>Movie lists</h1>
#     <p>Inception</p>
#     <p>Interstellar</P>
#     <p>Fight Club</p>
#     <p>Bat Man</p>
#
#
#
# </body>
# </html>

# %%
from IPython.display import HTML

html_content = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>

    <h1>Favorite food</h1>
    <ol>
    <li>Pizza</li>
    <li>Burger</li>
    <li>Pasta</li>
    </ol>

    <h1>Travel destinations</h1>
    <dl>
    <dt>Paris</dt>
    <dt>New York</dt>
    <dt>Tokyo</dt>
    <dd>Paris is the capital of France.</dd>
    <dd>New York is the largest city in the United States.</dd>
    <dd>Tokyo is the capital of Japan.</dd>
    </dl>


</body>
</html>"""

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#
#     <h1>Favorite food</h1>
#     <ol>
#     <li>Pizza</li>
#     <li>Burger</li>
#     <li>Pasta</li>
#     </ol>
#
#     <h1>Travel destinations</h1>
#     <dl>
#     <dt>Paris</dt>
#     <dt>New York</dt>
#     <dt>Tokyo</dt>
#     <dd>Paris is the capital of France.</dd>
#     <dd>New York is the largest city in the United States.</dd>
#     <dd>Tokyo is the capital of Japan.</dd>
#     </dl>
#
#
# </body>
# </html>

# %%
from IPython.display import HTML

html_content = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
   <ul>
        <li><a href="https://youtube.com">YouTube</a></li>
        <li><a href="https://instagram.com">Instagram</a></li>
   </ul>
</body>
</html>"""

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#    <ul>
#         <li><a href="https://youtube.com">YouTube</a></li>
#         <li><a href="https://instagram.com">Instagram</a></li>
#    </ul>
# </body>
# </html>

# %%
from IPython.display import HTML

html_content = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>
   <ul>
        <li><a href="https://youtube.com" target="blank">YouTube</a></li>
        <li><a href="https://instagram.com" target="blank">Instagram</a></li>
   </ul>

</body>
</html>"""

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#    <ul>
#         <li><a href="https://youtube.com" target="blank">YouTube</a></li>
#         <li><a href="https://instagram.com" target="blank">Instagram</a></li>
#    </ul>
#
# </body>
# </html>

# %%
from IPython.display import HTML

html_content = """<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<title>Document</title>
</head>
<body>
 <h1>TONY</h1>
 <p>ironman</p>
 <p>doomsday</p>

 </body>
 </html>"""

HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Document</title>
# </head>
# <body>
#  <h1>TONY</h1>
#  <p>ironman</p>
#  <p>doomsday</p>
#
#  </body>
#  </html>

# %%
from IPython.display import HTML

html_content = """<a target="_blank" href="https://www.google.com">Google</a>
<a target="_self" href="https://www.google.com">Google</a>
<a target="_parent" href="https://www.google.com">Google</a>
<a target="_top" href="https://www.google.com">Google</a>
<hr>
<iframe target="_blank"  src="https://www.flipkart.com" width="250" height="400"></iframe>
<iframe target="_self" src="https://www.amazon.com" width="250" height="400"></iframe>
<iframe target="_parent" src="https:wwwblinkit.com" width="250 height="400"></iframe>
<iframe target="_top" src="https://www.snapdeal.com" width="250" height="400"></iframe>
<iframe src="https://www.youtube.com/embed/ebrvE9KpCik?si=qinr23MGkll7Q30N" width="560" height="315" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
<iframe src="https://www.google.com/maps/embed?pb=!1m28!1m12!1m3!1d224580.22087454126!2d76.95591090074582!3d28.41726677372317!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!4m13!3e6!4m5!1s0x390ce3005b07521d%3A0xdd519dc41f269a33!2sIIT%20METRO%2C%20Technology%20Business%20Incubation%20Units%2C%201-6%2C%20Jia%20Sarai%2C%20Hauz%20Khas%2C%20New%20Delhi%2C%20Delhi%20110016%2C%20India!3m2!1d28.546383!2d77.19455099999999!4m5!1s0x390d25a4b2bc03f9%3A0x9f642d679654b239!%EF%BC%92sK.R.%EF%BC%92Mangalam%EF%BC%92University%EF%BC%92Sohna%EF%BC%92Gurgaon%EF%BC%92Rd%EF%BC%92Gurugram%EF%BC%92Sohna%EF%BC%92Rural%EF%BC%92Haryana%EF%BC%91%E2%82%82%E2%82%82%EF%BC%91%E2%82%80%E2%82%83%EF%BC%92India!%EF%BC%93m%E2%82%82!%EF%BC%91d%E2%82%82%E2%82%88.%E2%82%82%E2%82%87%E2%82%81%E2%82%87%E2%82%83%E2%82%82%E2%82%86%E2%82%89%E2%82%89%E2%82%89%E2%82%89%E2%82%89%E2%82%89%E2%82%88)!%E2%82%82d%E2%82%87%E2%82%87.%E2%82%80%E2%82%86%E2%82%89%E2%82%81%E2%82%87%E2%82%84%E2%82%86!%EF%BC%95e%E2%82%80!%EF%BC%93m%E2%82%82!%EF%BC%91sen!%E2%82%82suk!%EF%BC%94v%E2%82%81%E2%82%87%E2%82%89%E2%82%85%E2%82%84%E2%82%83%E2%82%81%E2%82%87%E2%82%80%E2%82%88%C2%B3%E2%82%84!%EF%BC%95m%E2%82%82!%EF%BC%91sen!%E2%82%82suk" width="500" height=" 300" style="border:0;" allowfullscreen="" loading="lazy" referrerpolicy="strict-origin-when-cross-origin  width=500 height=""></iframe>
<iframe src="https://www.youtube.com/embed/egdYKLBswgk?si=RvgTZKnjllVqPjNb" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen width="560" height="315"></iframe>
"""

HTML(html_content)
# Out:
# <a target="_blank" href="https://www.google.com">Google</a>
# <a target="_self" href="https://www.google.com">Google</a>
# <a target="_parent" href="https://www.google.com">Google</a>
# <a target="_top" href="https://www.google.com">Google</a>
# <hr>
# <iframe target="_blank"  src="https://www.flipkart.com" width="250" height="400"></iframe>
# <iframe target="_self" src="https://www.amazon.com" width="250" height="400"></iframe>
# <iframe target="_parent" src="https:www.blinkit.com" width="250 height="400"></iframe>
# <iframe target="_top" src="https://www.snapdeal.com" width="250" height="400"></iframe>
# <iframe src="https://www.youtube.com/embed/ebrvE9KpCik?si=qinr23MGkll7Q30N" width="560" height="315" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
# ...

# %%
from IPython.display import HTML

html_content = """<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=2.0">
<title>Document</title>
</head>
<body>
 <h1>PETER PARKAR</h1>
 <p>spider-man</p>
 <p>lowda</p>
 <p>gwen</p>

  </body>
  </html>"""


HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=2.0">
# <title>Document</title>
# </head>
# <body>
#  <h1>PETER PARKAR</h1>
#  <p>spider-man</p>
#  <p>lowda</p>
#  <p>gwen</p>
#
#   </body>
#   </html>
